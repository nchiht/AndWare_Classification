# %%
# !pip install git+https://github.com/intel/openfl.git
# !pip install -r requirements_workflow_interface.txt

# Uncomment this if running in Google Colab
# !pip install -r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt
import os
os.environ["USERNAME"] = "colab"
# Out:
# Collecting git+https://github.com/intel/openfl.git
#   Cloning https://github.com/intel/openfl.git to /tmp/pip-req-build-ok3d__fw
#   Running command git clone --filter=blob:none --quiet https://github.com/intel/openfl.git /tmp/pip-req-build-ok3d__fw
#   Resolved https://github.com/intel/openfl.git to commit d4108fb49b2d932d3647b12a370e42a0231cbc40
#   Preparing metadata (setup.py) ... done
# Collecting Click==8.0.1 (from openfl==1.5)
#   Downloading click-8.0.1-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.4/97.4 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from openfl==1.5) (6.0.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from openfl==1.5) (2.2.1)
# Requirement already satisfied: cryptography>=3.4.6 in /usr/local/lib/python3.10/dist-packages (from openfl==1.5) (41.0.5)
# Collecting docker (from openfl==1.5)
#   Downloading docker-6.1.3-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 8.6 MB/s eta 0:00:00
# Collecting dynaconf==3.1.7 (from openfl==1.5)
#   Downloading dynaconf-3.1.7-py2.py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.6/200.6 kB 11.4 MB/s eta 0:00:00
# Collecting flatten_json (from openfl==1.5)
#   Downloading flatten_json-0.1.14-py3-none-any.whl (8.0 kB)
# Requirement already satisfied: grpcio>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from openfl==1.5) (1.59.2)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from openfl==1.5) (5.5.6)
# Collecting jupyterlab (from openfl==1.5)
#   Downloading jupyterlab-4.0.9-py3-none-any.whl (9.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 39.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openfl==1.5) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from openfl==1.5) (1.5.3)
# Requirement already satisfied: protobuf>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from openfl==1.5) (3.20.3)
# Requirement already satisfied: pyzmq<=24.0.1 in /usr/local/lib/python3.10/dist-packages (from openfl==1.5) (23.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from openfl==1.5) (2.31.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from openfl==1.5) (13.7.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from openfl==1.5) (1.2.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from openfl==1.5) (2.14.1)
# Collecting tensorboardX<=2.6 (from openfl==1.5)
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 16.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openfl==1.5) (4.66.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.4.6->openfl==1.5) (1.16.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboardX<=2.6->openfl==1.5) (23.2)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from docker->openfl==1.5) (2.0.7)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from docker->openfl==1.5) (1.6.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->openfl==1.5) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->openfl==1.5) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->openfl==1.5) (2023.7.22)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from flatten_json->openfl==1.5) (1.16.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel->openfl==1.5) (0.2.0)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->openfl==1.5) (7.34.0)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->openfl==1.5) (5.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel->openfl==1.5) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel->openfl==1.5) (6.3.2)
# Collecting async-lru>=1.0.0 (from jupyterlab->openfl==1.5)
#   Downloading async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: jinja2>=3.0.3 in /usr/local/lib/python3.10/dist-packages (from jupyterlab->openfl==1.5) (3.1.2)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.10/dist-packages (from jupyterlab->openfl==1.5) (5.5.0)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->openfl==1.5)
#   Downloading jupyter_lsp-2.2.1-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.0/66.0 kB 9.3 MB/s eta 0:00:00
# Collecting jupyter-server<3,>=2.4.0 (from jupyterlab->openfl==1.5)
#   Downloading jupyter_server-2.11.1-py3-none-any.whl (380 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.0/380.0 kB 29.6 MB/s eta 0:00:00
# Collecting jupyterlab-server<3,>=2.19.0 (from jupyterlab->openfl==1.5)
#   Downloading jupyterlab_server-2.25.2-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.10/dist-packages (from jupyterlab->openfl==1.5) (0.2.3)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from jupyterlab->openfl==1.5) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->openfl==1.5) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->openfl==1.5) (2023.3.post1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->openfl==1.5) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->openfl==1.5) (2.16.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->openfl==1.5) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->openfl==1.5) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->openfl==1.5) (3.2.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->openfl==1.5) (1.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->openfl==1.5) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->openfl==1.5) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->openfl==1.5) (3.5.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->openfl==1.5) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->openfl==1.5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->openfl==1.5) (3.0.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from async-lru>=1.0.0->jupyterlab->openfl==1.5) (4.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.4.6->openfl==1.5) (2.21)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->openfl==1.5) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->openfl==1.5) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->openfl==1.5) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->openfl==1.5) (1.3.1)
# Collecting jedi>=0.16 (from ipython>=5.0.0->ipykernel->openfl==1.5)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 61.7 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->openfl==1.5) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->openfl==1.5) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->openfl==1.5) (3.0.41)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->openfl==1.5) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->openfl==1.5) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->openfl==1.5) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=3.0.3->jupyterlab->openfl==1.5) (2.1.3)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (3.7.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (23.1.0)
# Collecting jupyter-client (from ipykernel->openfl==1.5)
#   Downloading jupyter_client-8.6.0-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.9/105.9 kB 14.9 MB/s eta 0:00:00
# Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5)
#   Downloading jupyter_events-0.9.0-py3-none-any.whl (18 kB)
# Collecting jupyter-server-terminals (from jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5)
#   Downloading jupyter_server_terminals-0.4.4-py3-none-any.whl (13 kB)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (6.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (5.9.2)
# Collecting overrides (from jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5)
#   Downloading overrides-7.4.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (0.18.0)
# Collecting pyzmq<=24.0.1 (from openfl==1.5)
#   Downloading pyzmq-24.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 62.8 MB/s eta 0:00:00
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (0.18.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core->jupyterlab->openfl==1.5) (4.0.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (2.13.1)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5)
#   Downloading json5-0.9.14-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (4.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->openfl==1.5) (0.1.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (1.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->openfl==1.5) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (2023.11.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (0.31.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (0.13.0)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5)
#   Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (2.19.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.0.0->ipykernel->openfl==1.5) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->openfl==1.5) (0.2.10)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->openfl==1.5) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->openfl==1.5) (3.2.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (21.2.0)
# Collecting fqdn (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5)
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5)
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting jsonpointer>1.13 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Collecting uri-template (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5)
#   Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: webcolors>=1.11 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (1.13)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (0.5.1)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5)
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 9.8 MB/s eta 0:00:00
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5)
#   Downloading types_python_dateutil-2.8.19.14-py3-none-any.whl (9.4 kB)
# Building wheels for collected packages: openfl
#   Building wheel for openfl (setup.py) ... done
#   Created wheel for openfl: filename=openfl-1.5-py3-none-any.whl size=10784727 sha256=50893349e490b82ad7b4a1b4f52a4b0bc4237c4c951eea61a54f016156c17ff7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tcn36yxs/wheels/f6/3c/d9/737f4ac0c34a1d61b6dfd70a66b90438754779ab630cc73420
# Successfully built openfl
# Installing collected packages: types-python-dateutil, json5, uri-template, tensorboardX, rfc3986-validator, rfc3339-validator, pyzmq, python-json-logger, overrides, jsonpointer, jedi, fqdn, flatten_json, dynaconf, Click, async-lru, jupyter-server-terminals, jupyter-client, docker, arrow, isoduration, jupyter-events, jupyter-server, jupyterlab-server, jupyter-lsp, jupyterlab, openfl
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 23.2.1
#     Uninstalling pyzmq-23.2.1:
#       Successfully uninstalled pyzmq-23.2.1
#   Attempting uninstall: Click
#     Found existing installation: click 8.1.7
#     Uninstalling click-8.1.7:
#       Successfully uninstalled click-8.1.7
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.24.0
#     Uninstalling jupyter-server-1.24.0:
#       Successfully uninstalled jupyter-server-1.24.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# notebook 6.5.5 requires jupyter-client<8,>=5.3.4, but you have jupyter-client 8.6.0 which is incompatible.
# Successfully installed Click-8.0.1 arrow-1.3.0 async-lru-2.0.4 docker-6.1.3 dynaconf-3.1.7 flatten_json-0.1.14 fqdn-1.5.1 isoduration-20.11.0 jedi-0.19.1 json5-0.9.14 jsonpointer-2.4 jupyter-client-8.6.0 jupyter-events-0.9.0 jupyter-lsp-2.2.1 jupyter-server-2.11.1 jupyter-server-terminals-0.4.4 jupyterlab-4.0.9 jupyterlab-server-2.25.2 openfl-1.5 overrides-7.4.0 python-json-logger-2.0.7 pyzmq-24.0.1 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 tensorboardX-2.6 types-python-dateutil-2.8.19.14 uri-template-1.3.0
# Collecting dill==0.3.6 (from -r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 1))
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 3.7 MB/s eta 0:00:00
# Collecting metaflow==2.7.15 (from -r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 2))
#   Downloading metaflow-2.7.15-py2.py3-none-any.whl (863 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 864.0/864.0 kB 14.0 MB/s eta 0:00:00
# Collecting ray==2.2.0 (from -r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 3))
#   Downloading ray-2.2.0-cp310-cp310-manylinux2014_x86_64.whl (57.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 MB 11.2 MB/s eta 0:00:00
# Collecting numpy==1.21.6 (from -r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 4))
#   Downloading numpy-1.21.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 67.8 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from metaflow==2.7.15->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 2)) (2.31.0)
# Collecting boto3 (from metaflow==2.7.15->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 2))
#   Downloading boto3-1.33.2-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.1/139.1 kB 10.6 MB/s eta 0:00:00
# Collecting pylint (from metaflow==2.7.15->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 2))
#   Downloading pylint-3.0.2-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.6/510.6 kB 42.6 MB/s eta 0:00:00
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from ray==2.2.0->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 3)) (23.1.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray==2.2.0->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 3)) (8.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray==2.2.0->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 3)) (3.13.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray==2.2.0->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 3)) (4.19.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray==2.2.0->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 3)) (1.0.7)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray==2.2.0->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 3)) (3.20.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from ray==2.2.0->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 3)) (6.0.1)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray==2.2.0->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 3)) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray==2.2.0->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 3)) (1.4.0)
# Collecting virtualenv>=20.0.24 (from ray==2.2.0->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 3))
#   Downloading virtualenv-20.24.7-py3-none-any.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 104.0 MB/s eta 0:00:00
# Requirement already satisfied: grpcio>=1.42.0 in /usr/local/lib/python3.10/dist-packages (from ray==2.2.0->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 3)) (1.59.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ray==2.2.0->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 3)) (23.2)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.0.24->ray==2.2.0->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 3))
#   Downloading distlib-0.3.7-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 53.6 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.10/dist-packages (from virtualenv>=20.0.24->ray==2.2.0->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 3)) (4.0.0)
# Collecting botocore<1.34.0,>=1.33.2 (from boto3->metaflow==2.7.15->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 2))
#   Downloading botocore-1.33.2-py3-none-any.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 110.4 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->metaflow==2.7.15->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 2))
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.9.0,>=0.8.0 (from boto3->metaflow==2.7.15->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 2))
#   Downloading s3transfer-0.8.1-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 kB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.2.0->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 3)) (2023.11.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.2.0->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 3)) (0.31.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.2.0->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 3)) (0.13.0)
# Collecting astroid<=3.1.0-dev0,>=3.0.1 (from pylint->metaflow==2.7.15->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 2))
#   Downloading astroid-3.0.1-py3-none-any.whl (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.2/275.2 kB 34.4 MB/s eta 0:00:00
# Collecting isort<6,>=4.2.5 (from pylint->metaflow==2.7.15->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 2))
#   Downloading isort-5.12.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 13.9 MB/s eta 0:00:00
# Collecting mccabe<0.8,>=0.6 (from pylint->metaflow==2.7.15->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 2))
#   Downloading mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Collecting tomlkit>=0.10.1 (from pylint->metaflow==2.7.15->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 2))
#   Downloading tomlkit-0.12.3-py3-none-any.whl (37 kB)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from pylint->metaflow==2.7.15->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 2)) (2.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->metaflow==2.7.15->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 2)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->metaflow==2.7.15->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 2)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->metaflow==2.7.15->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 2)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->metaflow==2.7.15->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 2)) (2023.7.22)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from astroid<=3.1.0-dev0,>=3.0.1->pylint->metaflow==2.7.15->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 2)) (4.5.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.34.0,>=1.33.2->boto3->metaflow==2.7.15->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 2)) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.34.0,>=1.33.2->boto3->metaflow==2.7.15->-r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt (line 2)) (1.16.0)
# Installing collected packages: distlib, virtualenv, tomlkit, numpy, mccabe, jmespath, isort, dill, astroid, pylint, botocore, s3transfer, ray, boto3, metaflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# flax 0.7.5 requires numpy>=1.22, but you have numpy 1.21.6 which is incompatible.
# jax 0.4.20 requires numpy>=1.22, but you have numpy 1.21.6 which is incompatible.
# jaxlib 0.4.20+cuda11.cudnn86 requires numpy>=1.22, but you have numpy 1.21.6 which is incompatible.
# numba 0.58.1 requires numpy<1.27,>=1.22, but you have numpy 1.21.6 which is incompatible.
# plotnine 0.12.4 requires numpy>=1.23.0, but you have numpy 1.21.6 which is incompatible.
# tensorflow 2.14.0 requires numpy>=1.23.5, but you have numpy 1.21.6 which is incompatible.
# Successfully installed astroid-3.0.1 boto3-1.33.2 botocore-1.33.2 dill-0.3.6 distlib-0.3.7 isort-5.12.0 jmespath-1.0.1 mccabe-0.7.0 metaflow-2.7.15 numpy-1.21.6 pylint-3.0.2 ray-2.2.0 s3transfer-0.8.1 tomlkit-0.12.3 virtualenv-20.24.7

# %%
# !git clone 'https://github.com/Luis-P-Duarte/Projeto-IA-22-23-Malware-Android.git'
# !pip install rarfile
# Out:
# Cloning into 'Projeto-IA-22-23-Malware-Android'...
# remote: Enumerating objects: 227, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 227 (delta 26), reused 14 (delta 12), pack-reused 188
# Receiving objects: 100% (227/227), 130.71 MiB | 26.08 MiB/s, done.
# Resolving deltas: 100% (100/100), done.
# Updating files: 100% (67/67), done.
# Collecting rarfile
#   Downloading rarfile-4.1-py3-none-any.whl (28 kB)
# Installing collected packages: rarfile
# Successfully installed rarfile-4.1

# %%
import rarfile

# Đường dẫn đến tệp .rar trên Google Drive
rar_path = '/content/Projeto-IA-22-23-Malware-Android/Images/64x64.rar'

# Giải nén tệp .rar
with rarfile.RarFile(rar_path, 'r') as rf:
    rf.extractall('/content/data')

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split
from torchvision import transforms
from torchvision.datasets import ImageFolder
from sklearn.model_selection import train_test_split

# n_epochs = 3
batch_size_train = 64
batch_size_test = 32
log_interval = 5


# random_seed = 1
torch.backends.cudnn.enabled = False
# torch.manual_seed(random_seed)

# Custom dataset class
class CustomDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.dataset = ImageFolder(root_dir, transform=transform)

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        return self.dataset[idx]
# Define transformations
transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

])

# Load dataset
datasetfull = CustomDataset(root_dir='/content/data/64x64', transform=transform)

# Tính kích thước cho phần dữ liệu bạn muốn giữ lại (10%)
desired_size = int(0.5 * len(datasetfull))

# Tính kích thước cho phần còn lại của dữ liệu
remaining_size = len(datasetfull) - desired_size

# Tạo phần dữ liệu bạn muốn giữ lại
dataset, _ = random_split(datasetfull, [desired_size, remaining_size])

# Split dataset into train and validation sets
train_size = int(0.7 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

# %%
# Define your model
class MyModel(nn.Module):
    def __init__(self):
        super(MyModel, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=5, stride=1)
        self.pool = nn.MaxPool2d(2, stride=1)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(64 * 59 * 59, 500)
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(500, 5)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = self.flatten(x)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x


def inference(network, test_loader):
    if torch.cuda.is_available():
        network = network.to('cuda:0')
    network.eval()
    criterion = nn.CrossEntropyLoss()
    test_loss = 0
    correct = 0
    total_samples_val = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
          if torch.cuda.is_available():
                inputs = inputs.to('cuda:0')
                labels = labels.to('cuda:0')
          outputs = network(inputs)
          # test_loss += F.nll_loss(outputs, labels).item()
          test_loss += criterion(outputs, labels).item()
          _, predicted_val = torch.max(outputs.data, 1)
          total_samples_val += labels.size(0)
          correct += (predicted_val == labels).sum().item()

    test_loss /= total_samples_val
    accuracy = correct / total_samples_val

    print('\nTest set: Avg. loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss, correct, total_samples_val, 100. * accuracy))

    return accuracy

# %%
from copy import deepcopy

from openfl.experimental.interface import FLSpec, Aggregator, Collaborator
from openfl.experimental.runtime import LocalRuntime
from openfl.experimental.placement import aggregator, collaborator


def FedAvg(models, weights=None):
    models = [model.to('cpu') for model in models]
    new_model = models[0]
    state_dicts = [model.state_dict() for model in models]
    state_dict = new_model.state_dict()
    for key in models[1].state_dict():
        state_dict[key] = torch.from_numpy(np.average([state[key].numpy() for state in state_dicts],
                                                      axis=0,
                                                      weights=weights))
    new_model.load_state_dict(state_dict)
    return new_model

# %%
class FederatedFlow(FLSpec):

    def __init__(self, model = None, optimizer = None, criterion = None, rounds=5, **kwargs):
        super().__init__(**kwargs)
        if model is not None:
            self.model = model
            self.optimizer = optimizer
            self.criterion = criterion
        else:
            self.model = MyModel()
            self.optimizer = optim.Adam(self.model.parameters(), lr=0.001)
            self.criterion = nn.CrossEntropyLoss()
        self.rounds = rounds

    @aggregator
    def start(self):
        print(f'Performing initialization for model')
        self.collaborators = self.runtime.collaborators
        self.private = 10
        self.current_round = 0
        self.next(self.aggregated_model_validation,foreach='collaborators',exclude=['private'])

    @collaborator
    def aggregated_model_validation(self):
        print(f'Performing aggregated model validation for collaborator {self.input}')
        self.agg_validation_score = inference(self.model,self.test_loader)
        print(f'{self.input} value of {self.agg_validation_score}')
        self.next(self.train)

    @collaborator
    def train(self):
      if torch.cuda.is_available():
        self.model = self.model.to('cuda:0')
      self.model.train()
      self.optimizer = optim.Adam(self.model.parameters(), lr=0.001)
      self.criterion = nn.CrossEntropyLoss()
      total_correct = 0
      total_samples = 0

      for batch_idx, (inputs, labels) in enumerate(self.train_loader):
        if torch.cuda.is_available():
          inputs = inputs.to("cuda:0")
          labels = labels.to("cuda:0")
        self.optimizer.zero_grad()
        outputs = self.model(inputs)
        loss = self.criterion(outputs, labels)
        loss.backward()
        self.optimizer.step()

        # _, predicted = torch.max(outputs.data, 1)
        # total_samples += labels.size(0)
        # total_correct += (predicted == labels).sum().item()
        if batch_idx % log_interval == 0:
          print('Train Epoch: 1 [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
             batch_idx * len(inputs), len(self.train_loader.dataset),
            100. * batch_idx / len(self.train_loader), loss.item()))
          self.loss = loss.item()
          torch.save(self.model.state_dict(), 'model.pth')
          torch.save(self.optimizer.state_dict(), 'optimizer.pth')

      # train_accuracy = total_correct / total_samples
      # print ('Accuracy trainning: {}'.format(train_accuracy))
      self.training_completed = True
      self.next(self.local_model_validation)

    @collaborator
    def local_model_validation(self):
        self.local_validation_score = inference(self.model,self.test_loader)
        print(f'Doing local model validation for collaborator {self.input}: {self.local_validation_score}')
        self.next(self.join, exclude=['training_completed'])

    @aggregator
    def join(self,inputs):
        self.average_loss = sum(input.loss for input in inputs)/len(inputs)
        self.aggregated_model_accuracy = sum(input.agg_validation_score for input in inputs)/len(inputs)
        self.local_model_accuracy = sum(input.local_validation_score for input in inputs)/len(inputs)
        print(f'Average aggregated model validation values = {self.aggregated_model_accuracy}')
        print(f'Average training loss = {self.average_loss}')
        print(f'Average local model validation values = {self.local_model_accuracy}')
        self.model = FedAvg([input.model for input in inputs])
        self.optimizer = [input.optimizer for input in inputs][0]
        self.current_round += 1
        if self.current_round < self.rounds:
            self.next(self.aggregated_model_validation, foreach='collaborators', exclude=['private'])
        else:
            self.next(self.end)

    @aggregator
    def end(self):
        print(f'This is the end of the flow')
# Out:
# Aggregator step "start" registered
# Collaborator step "aggregated_model_validation" registered
# Collaborator step "train" registered
# Collaborator step "local_model_validation" registered
# Aggregator step "join" registered
# Aggregator step "end" registered

# %%
# Setup participants
aggregator = Aggregator()
aggregator.private_attributes = {}

# Setup collaborators with private attributes
collaborator_names = ['A', 'B', 'C']
collaborators = [Collaborator(name=name) for name in collaborator_names]
for idx, collaborator in enumerate(collaborators):
    local_train = deepcopy(train_dataset)
    local_test = deepcopy(val_dataset)
    indices_train = list(range(idx, len(train_dataset), len(collaborators)))
    local_train = torch.utils.data.Subset(train_dataset, indices_train)
    indices_val = list(range(idx, len(val_dataset), len(collaborators)))
    local_test = torch.utils.data.Subset(val_dataset, indices_val)
    collaborator.private_attributes = {
            'train_loader': torch.utils.data.DataLoader(local_train,batch_size=batch_size_train, shuffle=True),
            'test_loader': torch.utils.data.DataLoader(local_test,batch_size=batch_size_train, shuffle=True)
    }

local_runtime = LocalRuntime(aggregator=aggregator, collaborators=collaborators, backend='single_process')
print(f'Local runtime collaborators = {local_runtime.collaborators}')
# Out:
# Local runtime collaborators = ['A', 'B', 'C']

# %%
model = None
best_model = None
optimizer = None
criterion = None
flflow = FederatedFlow(model,optimizer)
flflow.runtime = local_runtime
flflow.run()
# Out:
# Creating local datastore in current directory (/content/.metaflow)
#
# Calling start
# Performing initialization for model
# Sending state from aggregator to collaborators
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator A
#
# Test set: Avg. loss: 0.0250, Accuracy: 172/831 (20.70%)
#
# A value of 0.2069795427196149
#
# Calling train
# Train Epoch: 1 [0/1939 (0%)]	Loss: 1.594406
# Train Epoch: 1 [320/1939 (16%)]	Loss: 16.405876
# Train Epoch: 1 [640/1939 (32%)]	Loss: 14.432997
# Train Epoch: 1 [960/1939 (48%)]	Loss: 7.417697
# Train Epoch: 1 [1280/1939 (65%)]	Loss: 3.574429
# Train Epoch: 1 [1600/1939 (81%)]	Loss: 3.978944
# Train Epoch: 1 [570/1939 (97%)]	Loss: 2.212901
#
# Calling local_model_validation
#
# Test set: Avg. loss: 0.0156, Accuracy: 613/831 (73.77%)
#
# Doing local model validation for collaborator A: 0.7376654632972323
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator B
#
# Test set: Avg. loss: 0.0250, Accuracy: 190/831 (22.86%)
#
# B value of 0.2286401925391095
#
# Calling train
# Train Epoch: 1 [0/1939 (0%)]	Loss: 1.596514
# Train Epoch: 1 [320/1939 (16%)]	Loss: 36.320187
# Train Epoch: 1 [640/1939 (32%)]	Loss: 9.439184
# Train Epoch: 1 [960/1939 (48%)]	Loss: 9.585552
# Train Epoch: 1 [1280/1939 (65%)]	Loss: 2.578274
# Train Epoch: 1 [1600/1939 (81%)]	Loss: 1.573750
# Train Epoch: 1 [570/1939 (97%)]	Loss: 0.771767
#
# Calling local_model_validation
#
# Test set: Avg. loss: 0.0109, Accuracy: 648/831 (77.98%)
#
# Doing local model validation for collaborator B: 0.779783393501805
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator C
#
# Test set: Avg. loss: 0.0250, Accuracy: 173/831 (20.82%)
#
# C value of 0.20818291215403129
#
# Calling train
# Train Epoch: 1 [0/1939 (0%)]	Loss: 1.613183
# Train Epoch: 1 [320/1939 (16%)]	Loss: 33.542984
# Train Epoch: 1 [640/1939 (32%)]	Loss: 9.466170
# Train Epoch: 1 [960/1939 (48%)]	Loss: 6.324962
# Train Epoch: 1 [1280/1939 (65%)]	Loss: 2.070626
# Train Epoch: 1 [1600/1939 (81%)]	Loss: 2.964309
# Train Epoch: 1 [570/1939 (97%)]	Loss: 1.216738
#
# Calling local_model_validation
#
# Test set: Avg. loss: 0.0155, Accuracy: 640/831 (77.02%)
#
# Doing local model validation for collaborator C: 0.7701564380264742
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values = 0.21460088247091857
# Average training loss = 1.4004686276117961
# Average local model validation values = 0.7625350982751705
# Sending state from aggregator to collaborators
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator A
#
# Test set: Avg. loss: 0.0150, Accuracy: 529/831 (63.66%)
#
# A value of 0.6365824308062575
#
# Calling train
# Train Epoch: 1 [0/1939 (0%)]	Loss: 0.879878
# Train Epoch: 1 [320/1939 (16%)]	Loss: 0.898868
# Train Epoch: 1 [640/1939 (32%)]	Loss: 0.792230
# Train Epoch: 1 [960/1939 (48%)]	Loss: 0.762991
# Train Epoch: 1 [1280/1939 (65%)]	Loss: 0.575964
# Train Epoch: 1 [1600/1939 (81%)]	Loss: 0.618579
# Train Epoch: 1 [570/1939 (97%)]	Loss: 0.920833
#
# Calling local_model_validation
#
# Test set: Avg. loss: 0.0091, Accuracy: 679/831 (81.71%)
#
# Doing local model validation for collaborator A: 0.8170878459687124
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator B
#
# Test set: Avg. loss: 0.0146, Accuracy: 517/831 (62.21%)
#
# B value of 0.6221419975932612
#
# Calling train
# Train Epoch: 1 [0/1939 (0%)]	Loss: 1.044412
# Train Epoch: 1 [320/1939 (16%)]	Loss: 1.745307
# Train Epoch: 1 [640/1939 (32%)]	Loss: 0.753262
# Train Epoch: 1 [960/1939 (48%)]	Loss: 0.744766
# Train Epoch: 1 [1280/1939 (65%)]	Loss: 0.734015
# Train Epoch: 1 [1600/1939 (81%)]	Loss: 0.679690
# Train Epoch: 1 [570/1939 (97%)]	Loss: 0.568819
#
# Calling local_model_validation
#
# Test set: Avg. loss: 0.0081, Accuracy: 682/831 (82.07%)
#
# Doing local model validation for collaborator B: 0.8206979542719615
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator C
#
# Test set: Avg. loss: 0.0138, Accuracy: 564/831 (67.87%)
#
# C value of 0.6787003610108303
#
# Calling train
# Train Epoch: 1 [0/1939 (0%)]	Loss: 1.057971
# Train Epoch: 1 [320/1939 (16%)]	Loss: 0.956026
# Train Epoch: 1 [640/1939 (32%)]	Loss: 0.518350
# Train Epoch: 1 [960/1939 (48%)]	Loss: 1.019692
# Train Epoch: 1 [1280/1939 (65%)]	Loss: 0.666367
# Train Epoch: 1 [1600/1939 (81%)]	Loss: 0.619256
# Train Epoch: 1 [570/1939 (97%)]	Loss: 0.462223
#
# Calling local_model_validation
#
# Test set: Avg. loss: 0.0081, Accuracy: 668/831 (80.39%)
#
# Doing local model validation for collaborator C: 0.8038507821901324
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values = 0.6458082631367831
# Average training loss = 0.650624950726827
# Average local model validation values = 0.8138788608102687
# Sending state from aggregator to collaborators
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator A
#
# Test set: Avg. loss: 0.0117, Accuracy: 654/831 (78.70%)
#
# A value of 0.7870036101083032
#
# Calling train
# Train Epoch: 1 [0/1939 (0%)]	Loss: 0.763084
# Train Epoch: 1 [320/1939 (16%)]	Loss: 0.808794
# Train Epoch: 1 [640/1939 (32%)]	Loss: 0.397456
# Train Epoch: 1 [960/1939 (48%)]	Loss: 0.460080
# Train Epoch: 1 [1280/1939 (65%)]	Loss: 0.549744
# Train Epoch: 1 [1600/1939 (81%)]	Loss: 0.633433
# Train Epoch: 1 [570/1939 (97%)]	Loss: 0.899950
#
# Calling local_model_validation
#
# Test set: Avg. loss: 0.0082, Accuracy: 685/831 (82.43%)
#
# Doing local model validation for collaborator A: 0.8243080625752106
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator B
#
# Test set: Avg. loss: 0.0114, Accuracy: 680/831 (81.83%)
#
# B value of 0.8182912154031288
#
# Calling train
# Train Epoch: 1 [0/1939 (0%)]	Loss: 0.699665
# Train Epoch: 1 [320/1939 (16%)]	Loss: 0.846452
# Train Epoch: 1 [640/1939 (32%)]	Loss: 0.594966
# Train Epoch: 1 [960/1939 (48%)]	Loss: 0.554548
# Train Epoch: 1 [1280/1939 (65%)]	Loss: 0.634436
# Train Epoch: 1 [1600/1939 (81%)]	Loss: 0.383950
# Train Epoch: 1 [570/1939 (97%)]	Loss: 0.745324
#
# Calling local_model_validation
#
# Test set: Avg. loss: 0.0083, Accuracy: 690/831 (83.03%)
#
# Doing local model validation for collaborator B: 0.8303249097472925
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator C
#
# Test set: Avg. loss: 0.0105, Accuracy: 683/831 (82.19%)
#
# C value of 0.8219013237063778
#
# Calling train
# Train Epoch: 1 [0/1939 (0%)]	Loss: 0.553610
# Train Epoch: 1 [320/1939 (16%)]	Loss: 0.460942
# Train Epoch: 1 [640/1939 (32%)]	Loss: 0.580564
# Train Epoch: 1 [960/1939 (48%)]	Loss: 0.582922
# Train Epoch: 1 [1280/1939 (65%)]	Loss: 0.657391
# Train Epoch: 1 [1600/1939 (81%)]	Loss: 0.550214
# Train Epoch: 1 [570/1939 (97%)]	Loss: 0.574969
#
# Calling local_model_validation
#
# Test set: Avg. loss: 0.0062, Accuracy: 716/831 (86.16%)
#
# Doing local model validation for collaborator C: 0.8616125150421179
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values = 0.8090653830726032
# Average training loss = 0.7400811115900675
# Average local model validation values = 0.8387484957882071
# Sending state from aggregator to collaborators
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator A
#
# Test set: Avg. loss: 0.0080, Accuracy: 689/831 (82.91%)
#
# A value of 0.8291215403128761
#
# Calling train
# Train Epoch: 1 [0/1939 (0%)]	Loss: 0.430283
# Train Epoch: 1 [320/1939 (16%)]	Loss: 0.463048
# Train Epoch: 1 [640/1939 (32%)]	Loss: 0.449784
# Train Epoch: 1 [960/1939 (48%)]	Loss: 0.474594
# Train Epoch: 1 [1280/1939 (65%)]	Loss: 0.451367
# Train Epoch: 1 [1600/1939 (81%)]	Loss: 0.490545
# Train Epoch: 1 [570/1939 (97%)]	Loss: 0.211710
#
# Calling local_model_validation
#
# Test set: Avg. loss: 0.0066, Accuracy: 712/831 (85.68%)
#
# Doing local model validation for collaborator A: 0.8567990373044525
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator B
#
# Test set: Avg. loss: 0.0075, Accuracy: 715/831 (86.04%)
#
# B value of 0.8604091456077015
#
# Calling train
# Train Epoch: 1 [0/1939 (0%)]	Loss: 0.432735
# Train Epoch: 1 [320/1939 (16%)]	Loss: 0.578813
# Train Epoch: 1 [640/1939 (32%)]	Loss: 0.449265
# Train Epoch: 1 [960/1939 (48%)]	Loss: 0.485698
# Train Epoch: 1 [1280/1939 (65%)]	Loss: 0.537011
# Train Epoch: 1 [1600/1939 (81%)]	Loss: 0.320552
# Train Epoch: 1 [570/1939 (97%)]	Loss: 0.762423
#
# Calling local_model_validation
#
# Test set: Avg. loss: 0.0073, Accuracy: 699/831 (84.12%)
#
# Doing local model validation for collaborator B: 0.8411552346570397
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator C
#
# Test set: Avg. loss: 0.0068, Accuracy: 721/831 (86.76%)
#
# C value of 0.8676293622141997
#
# Calling train
# Train Epoch: 1 [0/1939 (0%)]	Loss: 0.461876
# Train Epoch: 1 [320/1939 (16%)]	Loss: 0.465087
# Train Epoch: 1 [640/1939 (32%)]	Loss: 0.732609
# Train Epoch: 1 [960/1939 (48%)]	Loss: 0.720724
# Train Epoch: 1 [1280/1939 (65%)]	Loss: 0.546076
# Train Epoch: 1 [1600/1939 (81%)]	Loss: 0.573826
# Train Epoch: 1 [570/1939 (97%)]	Loss: 0.323114
#
# Calling local_model_validation
#
# Test set: Avg. loss: 0.0068, Accuracy: 721/831 (86.76%)
#
# Doing local model validation for collaborator C: 0.8676293622141997
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values = 0.8523866827115926
# Average training loss = 0.4324156145254771
# Average local model validation values = 0.8551945447252306
# Sending state from aggregator to collaborators
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator A
#
# Test set: Avg. loss: 0.0066, Accuracy: 725/831 (87.24%)
#
# A value of 0.8724428399518652
#
# Calling train
# Train Epoch: 1 [0/1939 (0%)]	Loss: 0.377172
# Train Epoch: 1 [320/1939 (16%)]	Loss: 0.341604
# Train Epoch: 1 [640/1939 (32%)]	Loss: 0.230726
# Train Epoch: 1 [960/1939 (48%)]	Loss: 0.358221
# Train Epoch: 1 [1280/1939 (65%)]	Loss: 0.478570
# Train Epoch: 1 [1600/1939 (81%)]	Loss: 0.461900
# Train Epoch: 1 [570/1939 (97%)]	Loss: 0.684258
#
# Calling local_model_validation
#
# Test set: Avg. loss: 0.0064, Accuracy: 721/831 (86.76%)
#
# Doing local model validation for collaborator A: 0.8676293622141997
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator B
#
# Test set: Avg. loss: 0.0064, Accuracy: 736/831 (88.57%)
#
# B value of 0.8856799037304453
#
# Calling train
# Train Epoch: 1 [0/1939 (0%)]	Loss: 0.389258
# Train Epoch: 1 [320/1939 (16%)]	Loss: 0.597188
# Train Epoch: 1 [640/1939 (32%)]	Loss: 0.604644
# Train Epoch: 1 [960/1939 (48%)]	Loss: 0.272025
# Train Epoch: 1 [1280/1939 (65%)]	Loss: 0.627074
# Train Epoch: 1 [1600/1939 (81%)]	Loss: 0.332815
# Train Epoch: 1 [570/1939 (97%)]	Loss: 1.016346
#
# Calling local_model_validation
#
# Test set: Avg. loss: 0.0057, Accuracy: 727/831 (87.48%)
#
# Doing local model validation for collaborator B: 0.8748495788206979
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator C
#
# Test set: Avg. loss: 0.0056, Accuracy: 746/831 (89.77%)
#
# C value of 0.8977135980746089
#
# Calling train
# Train Epoch: 1 [0/1939 (0%)]	Loss: 0.351902
# Train Epoch: 1 [320/1939 (16%)]	Loss: 0.197285
# Train Epoch: 1 [640/1939 (32%)]	Loss: 0.514887
# Train Epoch: 1 [960/1939 (48%)]	Loss: 0.277832
# Train Epoch: 1 [1280/1939 (65%)]	Loss: 0.464323
# Train Epoch: 1 [1600/1939 (81%)]	Loss: 0.454393
# Train Epoch: 1 [570/1939 (97%)]	Loss: 0.894925
#
# Calling local_model_validation
#
# Test set: Avg. loss: 0.0049, Accuracy: 742/831 (89.29%)
#
# Doing local model validation for collaborator C: 0.8929001203369434
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values = 0.8852787805856398
# Average training loss = 0.865176240603129
# Average local model validation values = 0.8784596871239471
#
# Calling end
# This is the end of the flow

# %%
print(f'Sample of the final model weights: {flflow.model.state_dict()["conv1.weight"][0]}')

print(f'\nFinal aggregated model accuracy for {flflow.rounds} rounds of training: {flflow.aggregated_model_accuracy}')
# Out:
# Sample of the final model weights: tensor([[[-0.0544, -0.1091,  0.0255,  0.0579, -0.0309],
#          [ 0.0914, -0.0629,  0.0936,  0.0880,  0.0437],
#          [ 0.1027, -0.0730,  0.0280, -0.0058,  0.0347],
#          [-0.0363,  0.1092, -0.0624, -0.0241,  0.0141],
#          [-0.0217, -0.0477, -0.0955, -0.0672,  0.0383]],
#
#         [[ 0.0280, -0.0642,  0.0208,  0.0545,  0.0715],
#          [ 0.1274,  0.0133,  0.0597, -0.0747, -0.0691],
#          [ 0.1507,  0.0332,  0.0660, -0.0454,  0.0575],
#          [-0.0264,  0.0389, -0.0780,  0.0821, -0.0660],
#          [ 0.1424,  0.0880, -0.0802,  0.0401,  0.0039]],
#
#         [[ 0.0677,  0.0165, -0.0512,  0.0519,  0.0347],
#          [-0.0737,  0.0146, -0.0496,  0.0906, -0.0319],
#          [-0.0361,  0.0804, -0.0587, -0.0413, -0.0396],
#          [-0.1134,  0.0478,  0.0656,  0.0099, -0.1082],
#          [ 0.0855,  0.0728,  0.0448,  0.0166,  0.0472]]])
#
# Final aggregated model accuracy for 5 rounds of training: 0.8852787805856398
